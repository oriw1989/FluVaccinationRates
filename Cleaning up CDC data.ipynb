# %% [markdown]
# # Consolidating CDC data
#
# Data was collected from fluvaxview data on the general population: https://www.cdc.gov/flu/fluvaxview/interactive-general-population.htm
#
# Report data were downloaded for years 2013-14, 2014-15, 2015-16, 2016-17, and 2017-18

# %%
import pandas as pd
import numpy as np

# %%
def process_raw_fluvaxview(data_frame):
    """
    This will process the raw data that was generated from fluvaxview
    """
    
    
    data_frame.iloc[0,:] = data_frame.iloc[0,:].fillna(method='ffill')
    
    sample_data = data_frame

    to_fill = []
    for val in sample_data.columns:
        if 'Unnamed:' not in val:
            to_fill.append(val)
        else:
            to_fill.append(np.nan)

    sample_data.columns = pd.Series(data=to_fill).fillna(method='ffill')


    index = sample_data.index
    sample_data['index_place'] = index
    index = sample_data['index_place']
    index[0] = 'race_or_age' 
    sample_data['index_placeholder'] = pd.Series(index)
    sample_data = sample_data.set_index('index_placeholder')

#     return sample_data
    sample_data = sample_data.drop(labels=['index_place'], axis=1)


    sample_data = sample_data.transpose()


    months = ['Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May']

    month_column = []
    thing_to_fill_in = None
    for name in sample_data.Names:
        if name in months:
            thing_to_fill_in = name
        month_column.append(thing_to_fill_in)

    exp_column = []
    for name in sample_data.Names:
        if name in months:
            exp_column.append('avg')
        else:
            exp_column.append(name)


    sample_data['month'] = month_column
    sample_data['stats'] = exp_column


    sample_data = sample_data.drop(labels='Names', axis=1)


    regions = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
           'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
           'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa',
           'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
           'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
           'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
           'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
           'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
           'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
           'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'United States',
           'Region  1', 'Region  2', 'Region  3', 'Region  4', 'Region  5',
           'Region  6', 'Region  7', 'Region  8', 'Region  9', 'Region 10',
           'HP 2020 Target']
    
#     return sample_data

    sample_data = sample_data.melt(value_vars=regions, id_vars=['month', 'stats', 'race_or_age'])
    
    return sample_data

# %%
data_2013 = pd.read_excel('../fluvaxdata/2013-2014 flu data.xlsx')
data_2014 = pd.read_excel('../fluvaxdata/2014-2015 flu data.xlsx')
data_2015 = pd.read_excel('../fluvaxdata/2015-2016 flu data.xlsx')
data_2016 = pd.read_excel('../fluvaxdata/2016-2017 flu data.xlsx')
data_2017 = pd.read_excel('../fluvaxdata/2017-2018 flu data.xlsx')

data_2013 = process_raw_fluvaxview(data_2013)
data_2014 = process_raw_fluvaxview(data_2014) 
data_2015 = process_raw_fluvaxview(data_2015) 
data_2016 = process_raw_fluvaxview(data_2016) 
data_2017 = process_raw_fluvaxview(data_2017) 

data_2013['year'] = '2013-2014'
data_2014['year'] = '2014-2015'
data_2015['year'] = '2015-2016'
data_2016['year'] = '2016-2017'
data_2017['year'] = '2017-2018'

data = data_2015.append(data_2016)
data = data.append(data_2017)
data = data.append(data_2014)
data = data.append(data_2013)

data.columns = ['month', 'stats', 'race_or_age', 'state_or_region', 'value', 'year']

data.head()
# Out:
#   month   stats race_or_age state_or_region   value       year
# 0   Jul     avg   ≥6 months         Alabama     0.9  2015-2016
# 1   Jul      LL   ≥6 months         Alabama     0.5  2015-2016
# 2   Jul      UL   ≥6 months         Alabama     1.3  2015-2016
# 3   Jul      CI   ≥6 months         Alabama  (±0.4)  2015-2016
# 4   Jul  SAMPLE   ≥6 months         Alabama    7822  2015-2016

# %%
data.to_csv('../fluvaxdata/2013-2018_consolidated_flu_data.csv')

# %% [markdown]
# # Processing consolidated CDC data
#
# Read the CDC consolidated dataframe, and set up some preliminary variables

# %%
import pandas as pd
cdc = pd.read_csv("../fluvaxdata/2013-2018_consolidated_flu_data.csv")

# %%
state_names = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# %% [markdown]
# As we see from the sample, there are multiple statistics and regions being considered

# %%
cdc.sample(20)
# Out:
#         Unnamed: 0 month   stats                   race_or_age  \
# 92800        30430   Oct     avg                     ≥65 years
# 102145       39775   Sep     avg                    5-12 years
# 280771       31291   Aug     avg                   50-64 years
# 284828       35348   Jul     avg      White only, non-Hispanic
# 197277       10167   Apr      UL                   13-17 years
# 238958       51848   Feb      CI                   18-64 years
# 154076       29336   Nov      LL  18-49 years not at high risk
# 184005       59265   Jan     avg      Black only, non-Hispanic
# 56725        56725   Nov     avg                     ≥18 years
# 301132       51652   Jul      LL                     ≥18 years
# 201163       14053   Dec      CI                    5-12 years
# 17691        17691   Feb      LL      Black only, non-Hispanic
# 188034         924   Mar  SAMPLE                      Hispanic
# 243445       56335   Oct     avg                      Hispanic
# 278821       29341   Jan      LL                   50-64 years
# 172983       48243   Aug      CI                     ≥65 years
# 19483        19483   Sep      CI                   50-64 years
# 51044        51044   Jul  SAMPLE      18-49 years at high risk
# 169960       45220   Sep     avg                   50-64 years
# 212907       25797   Jul      UL           6 months - 17 years
#
#        state_or_region   value       year
# 92800       New Jersey    41.0  2016-2017
# 102145  South Carolina    13.8  2016-2017
# 280771      New Mexico     0.8  2013-2014
# 284828            Ohio    NR †  2013-2014
# 197277         Georgia    48.8  2014-2015
# 238958       Region  1  (±1.8)  2014-2015
# 154076   New Hampshire    18.8  2017-2018
# 184005       Region  8    38.8  2017-2018
# 56725        Region  6    32.2  2015-2016
# 301132       Region  1     0.2  2013-2014
# 201163         Indiana  (±4.8)  2014-2015
# 17691         Kentucky    31.3  2015-2016
# 188034         Alabama     254  2014-2015
# 243445       Region  5    22.0  2014-2015
# 278821   New Hampshire    42.9  2013-2014
# 172983   West Virginia  (±0.6)  2017-2018
# 19483            Maine  (±1.2)  2015-2016
# 51044    United States   18662  2015-2016
# 169960         Vermont     5.4  2017-2018
# 212907         Montana     NaN  2014-2015

# %% [markdown]
# For our purposes, we only need the "avg" statistic, which indicates the percentage of patients covered by that date in the season. We only need state-by-state data:

# %%
cdc_avg = cdc[cdc["state_or_region"].isin(state_names) * cdc["stats"]=="avg"]

# %%
cdc_avg.sample(20)
# Out:
#         Unnamed: 0 month stats                            race_or_age  \
# 254350        4870   Mar   avg                               Hispanic
# 276616       27136   Nov   avg           18-64 years not at high risk
# 208640       21530   Dec   avg                              ≥65 years
# 9750          9750   Oct   avg               Black only, non-Hispanic
# 78400        16030   Dec   avg                             5-12 years
# 251921        2441   Dec   avg           18-64 years not at high risk
# 2540          2540   Sep   avg               18-49 years at high risk
# 259735       10255   Apr   avg                            18-64 years
# 37435        37435   Feb   avg               White only, non-Hispanic
# 98690        36320   Nov   avg                            50-64 years
# 6595          6595   May   avg           18-49 years not at high risk
# 209855       22745   Jan   avg  Other or multiple races, non-Hispanic
# 66010         3640   Sep   avg                            50-64 years
# 285583       36103   Mar   avg                            18-49 years
# 162310       37570   Aug   avg  Other or multiple races, non-Hispanic
# 2875          2875   Oct   avg                               Hispanic
# 264025       14545   Jul   avg                              ≥65 years
# 283442       33962   Mar   avg                            18-64 years
# 229680       42570   Jul   avg                              ≥6 months
# 188775        1665   Oct   avg                            50-64 years
#
#        state_or_region value       year
# 254350      California    NR  2013-2014
# 276616        Nebraska  33.1  2013-2014
# 208640   Massachusetts  59.6  2014-2015
# 9750           Florida  18.3  2015-2016
# 78400           Kansas  49.0  2016-2017
# 251921         Arizona  21.3  2013-2014
# 2540           Arizona   7.4  2015-2016
# 259735         Georgia  30.9  2013-2014
# 37435           Oregon  41.0  2015-2016
# 98690         Oklahoma  42.4  2016-2017
# 6595       Connecticut  35.3  2015-2016
# 209855        Michigan  41.5  2014-2015
# 66010         Arkansas   4.4  2016-2017
# 285583        Oklahoma  32.0  2013-2014
# 162310          Oregon  NR †  2017-2018
# 2875           Arizona  20.9  2015-2016
# 264025         Indiana  NR †  2013-2014
# 283442    North Dakota  39.7  2013-2014
# 229680           Texas   0.8  2014-2015
# 188775          Alaska  25.8  2014-2015

# %%
cdc_avg.shape
# Out:
# (49500, 7)

# %% [markdown]
# We need to remove all the "non-reported" values, and convert the rest to float.

# %%
#reomve "NR" values
cdc_avg_cleaned = cdc_avg[(cdc_avg["value"] != "NR †") & (cdc_avg["value"] != "NR *") & (cdc_avg["value"] != "NR")]
cdc_avg_cleaned["value_flt"] = cdc_avg_cleaned["value"].apply(float)
cdc_avg_cleaned.drop(columns=["Unnamed: 0"], inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
cdc_avg_cleaned.sample(20)
# Out:
#        month stats                            race_or_age state_or_region  \
# 190880   Jan   avg               White only, non-Hispanic        Arkansas
# 141695   Oct   avg                     6 months - 4 years        Kentucky
# 283047   Jan   avg  Other or multiple races, non-Hispanic  North Carolina
# 75710    Jan   avg           18-64 years not at high risk        Illinois
# 202885   Apr   avg                               Hispanic            Iowa
# 138915   Mar   avg                              ≥18 years         Indiana
# 152315   Nov   avg               Black only, non-Hispanic        Nebraska
# 173115   Jan   avg               Black only, non-Hispanic   West Virginia
# 277219   Nov   avg                    6 months - 17 years          Nevada
# 263352   Mar   avg                              ≥6 months         Indiana
# 197705   Feb   avg                            50-64 years         Georgia
# 261886   Jul   avg               18-49 years at high risk           Idaho
# 7200     May   avg                            13-17 years        Delaware
# 156810   Aug   avg               18-64 years at high risk        New York
# 48945    May   avg               18-64 years at high risk       Wisconsin
# 101660   Nov   avg                            50-64 years    Rhode Island
# 275961   Dec   avg               White only, non-Hispanic         Montana
# 11460    Nov   avg               18-49 years at high risk          Hawaii
# 234510   Apr   avg               Black only, non-Hispanic      Washington
# 5440     May   avg           18-64 years not at high risk        Colorado
#
#        value       year  value_flt
# 190880  46.5  2014-2015       46.5
# 141695  35.0  2017-2018       35.0
# 283047  43.5  2013-2014       43.5
# 75710   29.5  2016-2017       29.5
# 202885  56.6  2014-2015       56.6
# 138915  32.2  2017-2018       32.2
# 152315  36.3  2017-2018       36.3
# 173115  43.6  2017-2018       43.6
# 277219  39.0  2013-2014       39.0
# 263352  40.9  2013-2014       40.9
# 197705  39.9  2014-2015       39.9
# 261886   0.0  2013-2014        0.0
# 7200    52.7  2015-2016       52.7
# 156810   1.6  2017-2018        1.6
# 48945   39.2  2015-2016       39.2
# 101660  43.3  2016-2017       43.3
# 275961  37.5  2013-2014       37.5
# 11460   26.9  2015-2016       26.9
# 234510  49.2  2014-2015       49.2
# 5440    39.1  2015-2016       39.1

# %% [markdown]
# We now want just the full >= 6-months dataset

# %%
cdc_allpopulation = cdc_avg_cleaned[cdc_avg_cleaned.race_or_age == "≥6 months"]

# %% [markdown]
# Now compare the number of rows to the number of all possible data points for 5 years. We expect less due to some non-reported values.

# %%
cdc_allpopulation.shape
# Out:
# (2665, 7)

# %%
5*12*50
# Out:
# 3000

# %%
cdc_allpopulation.sample(20)
# Out:
#        month stats race_or_age state_or_region value       year  value_flt
# 156420   Jul   avg   ≥6 months        New York   0.7  2017-2018        0.7
# 10915    Dec   avg   ≥6 months          Hawaii  40.7  2015-2016       40.7
# 45575    Feb   avg   ≥6 months        Virginia  47.6  2015-2016       47.6
# 81210    Jan   avg   ≥6 months           Maine  46.3  2016-2017       46.3
# 93085    Dec   avg   ≥6 months      New Mexico  41.6  2016-2017       41.6
# 151490   Nov   avg   ≥6 months        Nebraska  38.8  2017-2018       38.8
# 218790   Jul   avg   ≥6 months        New York   0.7  2014-2015        0.7
# 109925   Feb   avg   ≥6 months   West Virginia  48.2  2016-2017       48.2
# 66370    Mar   avg   ≥6 months      California  47.7  2016-2017       47.7
# 67365    Apr   avg   ≥6 months        Colorado  49.7  2016-2017       49.7
# 249525   Apr   avg   ≥6 months         Alabama  47.9  2013-2014       47.9
# 85180    Mar   avg   ≥6 months       Minnesota  50.5  2016-2017       50.5
# 275208   Mar   avg   ≥6 months         Montana  41.2  2013-2014       41.2
# 194075   Feb   avg   ≥6 months        Delaware  52.2  2014-2015       52.2
# 77225    Aug   avg   ≥6 months            Iowa   2.0  2016-2017        2.0
# 289015   Oct   avg   ≥6 months  South Carolina  26.8  2013-2014       26.8
# 151505   Feb   avg   ≥6 months        Nebraska  46.1  2017-2018       46.1
# 236635   Dec   avg   ≥6 months         Wyoming  36.1  2014-2015       36.1
# 168350   May   avg   ≥6 months            Utah  38.5  2017-2018       38.5
# 249520   Mar   avg   ≥6 months         Alabama  46.7  2013-2014       46.7

# %% [markdown]
# We can now convert the dates to a more convenient time-stamp object, taking into account they way a 'season' is defined by CDC:

# %%
def convertToTimestamp(monthCol, yearCol):
    dateCol = []
    for (month, year) in zip(monthCol, yearCol):
        if (month in ["Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]):
            yr = year[0:4]
        else:
            yr = year[-4:]
        dateCol.append(pd.Timestamp.strptime(month + " 15 " + yr, "%b %d %Y"))
        
    return dateCol

# %%
cdc_allpopulation["time"] = convertToTimestamp(cdc_allpopulation["month"].values, cdc_allpopulation["year"].values)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Do some renaming of columns, and save the final dataframe

# %%
cdc_allpopulation.rename(columns={'value_flt': 'mean_pct', 'state_or_region': 'state'}, inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
cdc_allpopulation.sample(20)
# Out:
#        month stats race_or_age          state value       year  mean_pct  \
# 207905   Aug   avg   ≥6 months  Massachusetts   2.4  2014-2015       2.4
# 193055   Aug   avg   ≥6 months    Connecticut   1.6  2014-2015       1.6
# 230675   Aug   avg   ≥6 months           Utah   1.4  2014-2015       1.4
# 173290   Mar   avg   ≥6 months      Wisconsin  39.3  2017-2018      39.3
# 196030   Sep   avg   ≥6 months        Florida   9.1  2014-2015       9.1
# 149505   Oct   avg   ≥6 months       Missouri  26.6  2017-2018      26.6
# 90100    Sep   avg   ≥6 months         Nevada   9.1  2016-2017       9.1
# 221770   Sep   avg   ≥6 months           Ohio   9.2  2014-2015       9.2
# 94095    Apr   avg   ≥6 months       New York  49.2  2016-2017      49.2
# 47565    Apr   avg   ≥6 months  West Virginia  49.2  2015-2016      49.2
# 86180    May   avg   ≥6 months    Mississippi  40.1  2016-2017      40.1
# 94100    May   avg   ≥6 months       New York  49.8  2016-2017      49.8
# 232690   Mar   avg   ≥6 months       Virginia  51.5  2014-2015      51.5
# 12875    Aug   avg   ≥6 months       Illinois   2.6  2015-2016       2.6
# 137640   Jan   avg   ≥6 months       Illinois  37.3  2017-2018      37.3
# 259390   Jan   avg   ≥6 months        Georgia  36.9  2013-2014      36.9
# 64355    Aug   avg   ≥6 months        Arizona   2.5  2016-2017       2.5
# 212885   Feb   avg   ≥6 months        Montana  43.0  2014-2015      43.0
# 127750   Mar   avg   ≥6 months       Arkansas  41.4  2017-2018      41.4
# 208895   Aug   avg   ≥6 months       Michigan   1.2  2014-2015       1.2
#
#              time
# 207905 2014-08-15
# 193055 2014-08-15
# 230675 2014-08-15
# 173290 2018-03-15
# 196030 2014-09-15
# 149505 2017-10-15
# 90100  2016-09-15
# 221770 2014-09-15
# 94095  2017-04-15
# 47565  2016-04-15
# 86180  2017-05-15
# 94100  2017-05-15
# 232690 2015-03-15
# 12875  2015-08-15
# 137640 2018-01-15
# 259390 2014-01-15
# 64355  2016-08-15
# 212885 2015-02-15
# 127750 2018-03-15
# 208895 2014-08-15

# %%
cdc_allpopulation.to_csv("cdc_average_bystate_2013-2017.csv")
