# %% [markdown]
# # Consolidating CDC data
#
# Data was collected from fluvaxview data on the general population: https://www.cdc.gov/flu/fluvaxview/interactive-general-population.htm
#
# Report data were downloaded for years 2013-14, 2014-15, 2015-16, 2016-17, and 2017-18

# %%
import pandas as pd
import numpy as np

# %%
def process_raw_fluvaxview(data_frame):
    """
    This will process the raw data that was generated from fluvaxview
    """
    
    
    data_frame.iloc[0,:] = data_frame.iloc[0,:].fillna(method='ffill')
    
    sample_data = data_frame

    to_fill = []
    for val in sample_data.columns:
        if 'Unnamed:' not in val:
            to_fill.append(val)
        else:
            to_fill.append(np.nan)

    sample_data.columns = pd.Series(data=to_fill).fillna(method='ffill')


    index = sample_data.index
    sample_data['index_place'] = index
    index = sample_data['index_place']
    index[0] = 'race_or_age' 
    sample_data['index_placeholder'] = pd.Series(index)
    sample_data = sample_data.set_index('index_placeholder')

#     return sample_data
    sample_data = sample_data.drop(labels=['index_place'], axis=1)


    sample_data = sample_data.transpose()


    months = ['Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May']

    month_column = []
    thing_to_fill_in = None
    for name in sample_data.Names:
        if name in months:
            thing_to_fill_in = name
        month_column.append(thing_to_fill_in)

    exp_column = []
    for name in sample_data.Names:
        if name in months:
            exp_column.append('avg')
        else:
            exp_column.append(name)


    sample_data['month'] = month_column
    sample_data['stats'] = exp_column


    sample_data = sample_data.drop(labels='Names', axis=1)


    regions = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
           'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
           'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa',
           'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
           'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
           'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
           'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
           'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
           'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
           'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'United States',
           'Region  1', 'Region  2', 'Region  3', 'Region  4', 'Region  5',
           'Region  6', 'Region  7', 'Region  8', 'Region  9', 'Region 10',
           'HP 2020 Target']
    
#     return sample_data

    sample_data = sample_data.melt(value_vars=regions, id_vars=['month', 'stats', 'race_or_age'])
    
    return sample_data

# %%
data_2013 = pd.read_excel('data/2013-2014 flu data.xlsx')
data_2014 = pd.read_excel('data/2014-2015 flu data.xlsx')
data_2015 = pd.read_excel('data/2015-2016 flu data.xlsx')
data_2016 = pd.read_excel('data/2016-2017 flu data.xlsx')
data_2017 = pd.read_excel('data/2017-2018 flu data.xlsx')

data_2013 = process_raw_fluvaxview(data_2013)
data_2014 = process_raw_fluvaxview(data_2014) 
data_2015 = process_raw_fluvaxview(data_2015) 
data_2016 = process_raw_fluvaxview(data_2016) 
data_2017 = process_raw_fluvaxview(data_2017) 

data_2013['year'] = '2013-2014'
data_2014['year'] = '2014-2015'
data_2015['year'] = '2015-2016'
data_2016['year'] = '2016-2017'
data_2017['year'] = '2017-2018'

data = data_2015.append(data_2016)
data = data.append(data_2017)
data = data.append(data_2014)
data = data.append(data_2013)

data.columns = ['month', 'stats', 'race_or_age', 'state_or_region', 'value', 'year']

data.head()
# Out:
#   month   stats race_or_age state_or_region   value       year
# 0   Jul     avg   ≥6 months         Alabama     0.9  2015-2016
# 1   Jul      LL   ≥6 months         Alabama     0.5  2015-2016
# 2   Jul      UL   ≥6 months         Alabama     1.3  2015-2016
# 3   Jul      CI   ≥6 months         Alabama  (±0.4)  2015-2016
# 4   Jul  SAMPLE   ≥6 months         Alabama    7822  2015-2016

# %%
data.to_csv('data/2013-2018_consolidated_flu_data.csv')

# %% [markdown]
# # Processing consolidated CDC data
#
# Read the CDC consolidated dataframe, and set up some preliminary variables

# %%
import pandas as pd
cdc = pd.read_csv("data/2013-2018_consolidated_flu_data.csv")

# %%
state_names = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# %% [markdown]
# As we see from the sample, there are multiple statistics and regions being considered

# %%
cdc.sample(20)
# Out:
#         Unnamed: 0 month   stats                   race_or_age  \
# 253945        4465   Oct      CI                   18-49 years
# 103585       41215   Nov     avg  18-49 years not at high risk
# 175861       51121   Dec      LL  18-49 years not at high risk
# 188280        1170   Oct     avg                    5-12 years
# 118391       56021   Jan      LL      18-49 years at high risk
# 63255          885   Aug     avg                      Hispanic
# 217287       30177   Feb      UL  18-64 years not at high risk
# 204213       17103   May      CI                   13-17 years
# 196162        9052   Jan      UL            6 months - 4 years
# 289507       40027   Sep      UL                   18-49 years
# 137770       13030   May     avg            6 months - 4 years
# 79894        17524   Jan  SAMPLE                   50-64 years
# 269775       20295   Mar     avg                   18-49 years
# 275372       25892   Feb  SAMPLE                    5-12 years
# 223121       36011   Mar      LL                   18-64 years
# 289205       39725   Mar     avg                    5-12 years
# 211468       24358   Apr      CI      18-49 years at high risk
# 261680       12200   Sep  SAMPLE                   18-64 years
# 91335        28965   Feb     avg                   13-17 years
# 86456        24086   May      LL                     ≥18 years
#
#        state_or_region   value       year
# 253945      California  (±5.3)  2013-2014
# 103585    South Dakota    33.7  2016-2017
# 175861   United States    20.9  2017-2018
# 188280          Alaska    39.6  2014-2015
# 118391       Region  5    30.1  2016-2017
# 63255          Alabama     7.4  2016-2017
# 217287      New Jersey    35.4  2014-2015
# 204213        Kentucky  (±6.3)  2014-2015
# 196162         Florida    57.6  2014-2015
# 289507  South Carolina     6.5  2013-2014
# 137770        Illinois    70.0  2017-2018
# 79894         Kentucky    2170  2016-2017
# 269775        Maryland    34.4  2013-2014
# 275372         Montana     832  2013-2014
# 223121        Oklahoma    38.9  2014-2015
# 289205  South Carolina    57.3  2013-2014
# 211468     Mississippi  (±9.0)  2014-2015
# 261680           Idaho    3174  2013-2014
# 91335    New Hampshire    51.7  2016-2017
# 86456      Mississippi    34.5  2016-2017

# %% [markdown]
# For our purposes, we only need the "avg" statistic, which indicates the percentage of patients covered by that date in the season. We only need state-by-state data:

# %%
cdc_avg = cdc[cdc["state_or_region"].isin(state_names) * cdc["stats"]=="avg"]

# %%
cdc_avg.sample(20)
# Out:
#         Unnamed: 0 month stats                   race_or_age state_or_region  \
# 191415        4305   Oct   avg                   18-64 years      California
# 6290          6290   Nov   avg                   18-64 years     Connecticut
# 18195        18195   Apr   avg                   18-64 years       Louisiana
# 3225          3225   Feb   avg                   13-17 years        Arkansas
# 135705       10965   Nov   avg           6 months - 17 years          Hawaii
# 127310        2570   Mar   avg      18-49 years at high risk         Arizona
# 197070        9960   Aug   avg           6 months - 17 years         Georgia
# 134225        9485   Dec   avg      18-49 years at high risk         Florida
# 111495       49125   Sep   avg  18-49 years not at high risk       Wisconsin
# 95170        32800   Nov   avg            6 months - 4 years  North Carolina
# 278950       29470   May   avg      White only, non-Hispanic   New Hampshire
# 104255       41885   Jan   avg                     ≥18 years       Tennessee
# 11175        11175   Sep   avg                     ≥18 years          Hawaii
# 203120       16010   Aug   avg                    5-12 years          Kansas
# 260638       11158   Oct   avg                     ≥18 years          Hawaii
# 154680       29940   Nov   avg                   13-17 years      New Jersey
# 231320       44210   Apr   avg  18-49 years not at high risk            Utah
# 249570          90   Feb   avg           6 months - 17 years         Alabama
# 218835       31725   Apr   avg                     ≥6 months        New York
# 126510        1770   Sep   avg      White only, non-Hispanic          Alaska
#
#        value       year
# 191415  16.9  2014-2015
# 6290    34.1  2015-2016
# 18195   33.6  2015-2016
# 3225    54.5  2015-2016
# 135705  46.4  2017-2018
# 127310  30.0  2017-2018
# 197070   6.1  2014-2015
# 134225  18.2  2017-2018
# 111495   3.7  2016-2017
# 95170   55.3  2016-2017
# 278950  48.3  2013-2014
# 104255  36.0  2016-2017
# 11175   11.3  2015-2016
# 203120   3.3  2014-2015
# 260638  27.4  2013-2014
# 154680  42.2  2017-2018
# 231320  37.3  2014-2015
# 249570  58.3  2013-2014
# 218835  48.5  2014-2015
# 126510   8.3  2017-2018

# %%
cdc_avg.shape
# Out:
# (49500, 7)

# %% [markdown]
# We need to remove all the "non-reported" values, and convert the rest to float.

# %%
#reomve "NR" values
cdc_avg_cleaned = cdc_avg[(cdc_avg["value"] != "NR †") & (cdc_avg["value"] != "NR *") & (cdc_avg["value"] != "NR")]
cdc_avg_cleaned["value_flt"] = cdc_avg_cleaned["value"].apply(float)
cdc_avg_cleaned.drop(columns=["Unnamed: 0"], inplace=True)
# Out:
# /home/wmvoje/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/wmvoje/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
cdc_avg_cleaned.sample(20)
# Out:
#        month stats                            race_or_age state_or_region  \
# 143995   Aug   avg           18-64 years not at high risk           Maine
# 291594   Oct   avg           18-49 years not at high risk       Tennessee
# 152890   Apr   avg               18-64 years at high risk          Nevada
# 275033   Jan   avg               Black only, non-Hispanic        Missouri
# 204760   May   avg               White only, non-Hispanic        Kentucky
# 43380    Mar   avg               White only, non-Hispanic           Texas
# 68415    May   avg                    6 months - 17 years     Connecticut
# 168985   Dec   avg                            50-64 years            Utah
# 224745   Oct   avg                              ≥6 months    Pennsylvania
# 174000   Feb   avg                              ≥65 years       Wisconsin
# 143705   Apr   avg                     6 months - 4 years           Maine
# 3090     Sep   avg                     6 months - 4 years        Arkansas
# 132470   Jan   avg               White only, non-Hispanic        Delaware
# 42150    Nov   avg               18-49 years at high risk       Tennessee
# 235760   Jan   avg                     6 months - 4 years       Wisconsin
# 163150   Nov   avg               White only, non-Hispanic    Pennsylvania
# 18160    Sep   avg                            18-64 years       Louisiana
# 213145   Nov   avg                              ≥18 years         Montana
# 145835   Jan   avg                              ≥18 years   Massachusetts
# 165295   Nov   avg  Other or multiple races, non-Hispanic  South Carolina
#
#        value       year  value_flt
# 143995   0.9  2017-2018        0.9
# 291594  18.8  2013-2014       18.8
# 152890  39.3  2017-2018       39.3
# 275033  45.0  2013-2014       45.0
# 204760  48.5  2014-2015       48.5
# 43380   47.8  2015-2016       47.8
# 68415   68.6  2016-2017       68.6
# 168985  35.4  2017-2018       35.4
# 224745  31.0  2014-2015       31.0
# 174000  50.1  2017-2018       50.1
# 143705  73.4  2017-2018       73.4
# 3090    14.3  2015-2016       14.3
# 132470  46.3  2017-2018       46.3
# 42150   28.9  2015-2016       28.9
# 235760  65.7  2014-2015       65.7
# 163150  38.9  2017-2018       38.9
# 18160    5.9  2015-2016        5.9
# 213145  36.4  2014-2015       36.4
# 145835  40.2  2017-2018       40.2
# 165295  34.4  2017-2018       34.4

# %% [markdown]
# We now want just the full >= 6-months dataset

# %%
cdc_allpopulation = cdc_avg_cleaned[cdc_avg_cleaned.race_or_age == "≥6 months"]

# %% [markdown]
# Now compare the number of rows to the number of all possible data points for 5 years. We expect less due to some non-reported values.

# %%
cdc_allpopulation.shape
# Out:
# (2665, 7)

# %%
5*12*50
# Out:
# 3000

# %%
cdc_allpopulation.sample(20)
# Out:
#        month stats race_or_age state_or_region value       year  value_flt
# 278172   Mar   avg   ≥6 months   New Hampshire  47.6  2013-2014       47.6
# 36630    Jul   avg   ≥6 months          Oregon   0.4  2015-2016        0.4
# 173300   May   avg   ≥6 months       Wisconsin  40.4  2017-2018       40.4
# 214865   Feb   avg   ≥6 months          Nevada  37.8  2014-2015       37.8
# 215855   Feb   avg   ≥6 months   New Hampshire  51.0  2014-2015       51.0
# 292992   Mar   avg   ≥6 months            Utah  41.0  2013-2014       41.0
# 281096   Jul   avg   ≥6 months        New York   0.4  2013-2014        0.4
# 259375   Oct   avg   ≥6 months         Georgia  24.0  2013-2014       24.0
# 107945   Feb   avg   ≥6 months        Virginia  47.8  2016-2017       47.8
# 66380    May   avg   ≥6 months      California  48.0  2016-2017       48.0
# 171275   Aug   avg   ≥6 months      Washington   2.1  2017-2018        2.1
# 133690   Mar   avg   ≥6 months         Florida  34.5  2017-2018       34.5
# 252449   Aug   avg   ≥6 months        Arkansas   1.4  2013-2014        1.4
# 90130    Mar   avg   ≥6 months          Nevada  35.1  2016-2017       35.1
# 33685    Dec   avg   ≥6 months    North Dakota  44.2  2015-2016       44.2
# 214860   Jan   avg   ≥6 months          Nevada  35.8  2014-2015       35.8
# 104990   May   avg   ≥6 months           Texas  43.5  2016-2017       43.5
# 249505   Dec   avg   ≥6 months         Alabama  41.2  2013-2014       41.2
# 266281   Aug   avg   ≥6 months        Kentucky   1.8  2013-2014        1.8
# 25       Dec   avg   ≥6 months         Alabama  38.3  2015-2016       38.3

# %% [markdown]
# We can now convert the dates to a more convenient time-stamp object, taking into account they way a 'season' is defined by CDC:

# %%
def convertToTimestamp(monthCol, yearCol):
    dateCol = []
    for (month, year) in zip(monthCol, yearCol):
        if (month in ["Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]):
            yr = year[0:4]
        else:
            yr = year[-4:]
        dateCol.append(pd.Timestamp.strptime(month + " 15 " + yr, "%b %d %Y"))
        
    return dateCol

# %%
cdc_allpopulation["time"] = convertToTimestamp(cdc_allpopulation["month"].values, cdc_allpopulation["year"].values)
# Out:
# /home/wmvoje/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Do some renaming of columns, and save the final dataframe

# %%
cdc_allpopulation.rename(columns={'value_flt': 'mean_pct', 'state_or_region': 'state'}, inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
cdc_allpopulation.sample(20)
# Out:
#        month stats race_or_age state_or_region value       year  value_flt  \
# 107930   Nov   avg   ≥6 months        Virginia  39.2  2016-2017       39.2
# 229690   Sep   avg   ≥6 months           Texas  11.6  2014-2015       11.6
# 213890   May   avg   ≥6 months        Nebraska  54.0  2014-2015       54.0
# 144545   Aug   avg   ≥6 months        Maryland   2.2  2017-2018        2.2
# 170310   Jan   avg   ≥6 months        Virginia  44.0  2017-2018       44.0
# 87150    Jan   avg   ≥6 months        Missouri  44.7  2016-2017       44.7
# 262344   Nov   avg   ≥6 months        Illinois  35.2  2013-2014       35.2
# 188120   Nov   avg   ≥6 months          Alaska  35.1  2014-2015       35.1
# 157415   Aug   avg   ≥6 months  North Carolina   2.7  2017-2018        2.7
# 209890   Sep   avg   ≥6 months       Minnesota  10.2  2014-2015       10.2
# 146525   Aug   avg   ≥6 months        Michigan   1.7  2017-2018        1.7
# 128700   Jul   avg   ≥6 months      California   0.6  2017-2018        0.6
# 84180    Jan   avg   ≥6 months        Michigan  41.0  2016-2017       41.0
# 235670   May   avg   ≥6 months       Wisconsin  44.1  2014-2015       44.1
# 270258   Jan   avg   ≥6 months   Massachusetts  51.5  2013-2014       51.5
# 156420   Jul   avg   ≥6 months        New York   0.7  2017-2018        0.7
# 41595    Oct   avg   ≥6 months       Tennessee  27.3  2015-2016       27.3
# 208940   May   avg   ≥6 months        Michigan  44.3  2014-2015       44.3
# 258407   Feb   avg   ≥6 months         Florida  35.8  2013-2014       35.8
# 163360   Sep   avg   ≥6 months    Rhode Island   9.7  2017-2018        9.7
#
#              time
# 107930 2016-11-15
# 229690 2014-09-15
# 213890 2015-05-15
# 144545 2017-08-15
# 170310 2018-01-15
# 87150  2017-01-15
# 262344 2013-11-15
# 188120 2014-11-15
# 157415 2017-08-15
# 209890 2014-09-15
# 146525 2017-08-15
# 128700 2017-07-15
# 84180  2017-01-15
# 235670 2015-05-15
# 270258 2014-01-15
# 156420 2017-07-15
# 41595  2015-10-15
# 208940 2015-05-15
# 258407 2014-02-15
# 163360 2017-09-15

# %%
cdc_allpopulation.to_csv("data/cdc_average_bystate_2013-2017.csv")
